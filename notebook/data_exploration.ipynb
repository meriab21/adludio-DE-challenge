# %% [markdown]
# Data Exploration

# %%
# importing libraries
import pandas as pd

# %%
# importing dataset
briefing_data = pd.read_csv("../data/briefing.csv")
campaigns_data = pd.read_csv("../data/campaigns_inventory_updated.csv", low_memory=False)
glob_design_data = pd.read_json("../data/global_design_data.json", orient ='index')

# %%
#Observing briefings dataset
print(briefing_data.shape)
briefing_data.head()
# Out:
# (101, 21)
#   campaign_id                                      campaign_name  \
# 0     shg01yl  Lexus East | Boston | Sensory Video |  CPM - C...
# 1     rom3zao         Lexus East | Boston | Sensory Video |  CPM
# 2     lvkar9i         Lexus East | Boston | Sensory Video |  CPE
# 3     8muucqy      Lexus East | Boston | Sensory Video |  CPE AV
# 4     xygdmea  Lexus East | Boston | Sensory Video |  CPE - C...
#
#     Submission Date                                        Description  \
# 0  14/02/2020 14:48  Hey Kentaro - Below is the info for the Lexus ...
# 1  14/02/2020 14:48  Hey Kentaro - Below is the info for the Lexus ...
# 2  14/02/2020 14:48  Hey Kentaro - Below is the info for the Lexus ...
# 3  14/02/2020 14:48  Hey Kentaro - Below is the info for the Lexus ...
# 4  14/02/2020 14:48  Hey Kentaro - Below is the info for the Lexus ...
#
#   Campaign Objectives                  KPIs  \
# 0     Brand Awareness  CTR\nEngagement Rate
# ...

# %%
briefing_data.columns.tolist()
# Out:
# ['campaign_id',
#  'campaign_name',
#  'Submission Date',
#  'Description',
#  'Campaign Objectives',
#  'KPIs',
#  'Placement(s)',
#  'StartDate',
#  'EndDate',
#  'Serving Location(s)',
#  'Black/white/audience list included?',
#  'Delivery Requirements (Black/Audience/White List)',
#  'Cost Centre',
#  'Currency',
#  'Buy Rate (CPE)',
#  'Volume Agreed',
#  'Gross Cost/Budget',
#  'Agency Fee',
#  'Percentage',
#  'Flat Fee',
#  'Net Cost']

# %%
briefing_data.isnull().sum()
# Out:
# campaign_id                                            0
# campaign_name                                          0
# Submission Date                                        0
# Description                                            0
# Campaign Objectives                                    0
# KPIs                                                   0
# Placement(s)                                           0
# StartDate                                              0
# EndDate                                                0
# Serving Location(s)                                    0
# Black/white/audience list included?                    0
# Delivery Requirements (Black/Audience/White List)     92
# Cost Centre                                            0
# Currency                                               0
# Buy Rate (CPE)                                        23
# Volume Agreed                                         23
# ...

# %%
#Observing campaigns dataset
campaigns_data.head()
# Out:
#          type width height campaign_id creative_id  \
# 0  impression     %      %     l5kk3r3    x83byc8a
# 1  impression     %      %     l5kk3r3    x83byc8a
# 2  impression     %      %     l5kk3r3    tf2htrrm
# 3  impression     %      %     l5kk3r3    x83byc8a
# 4  impression     %      %     l5kk3r3    x83byc8a
#
#                              auction_id                browser_ts  \
# 0  fd74243f-6606-4830-a0ef-dd12f66ec6f5  2021-01-01T19:55:20.291Z
# 1  fd74243f-6606-4830-a0ef-dd12f66ec6f5  2021-01-01T19:55:20.298Z
# 2  b3af878b-fd1a-4c6f-91a2-4e3670d2fda5  2021-01-05T00:21:39.693Z
# 3  b7c22590-e784-43cf-874d-a661ad99601f  2021-01-06T09:30:44.188Z
# 4  b7c22590-e784-43cf-874d-a661ad99601f  2021-01-06T09:30:45.047Z
#
#                                             game_key geo_country  \
# 0  adunit-facebook-conversational-commerce-phase-...    Thailand
# 1  adunit-facebook-conversational-commerce-phase-...    Thailand
# ...

# %%
campaigns_data.columns.tolist()
# Out:
# ['type',
#  'width',
#  'height',
#  'campaign_id',
#  'creative_id',
#  'auction_id',
#  'browser_ts',
#  'game_key',
#  'geo_country',
#  'site_name',
#  'platform_os',
#  'device_type',
#  'browser']

# %%
campaigns_data.type.unique()
# Out:
# array(['impression', 'first_dropped', 'click-through-event'], dtype=object)

# %%
glob_design_data.head(1)
# Out:
#                                                                1028d033d74dd2e24f67  \
# f910338e60315f02812b05e932068f47  {'labels': {'engagement': ['Asphalt', 'Tarmac'...
#
#                                  9e1c545a4b490a7c3088 e7370ccd417a54394cfc  \
# f910338e60315f02812b05e932068f47                  NaN                  NaN
#
#                                  a034c30acd4658d468a4 8fd373d2d72b97b68c49  \
# f910338e60315f02812b05e932068f47                  NaN                  NaN
#
#                                  83f4b8d153f1fde2d2a8 acf7bfc2db5043ca0d0b  \
# f910338e60315f02812b05e932068f47                  NaN                  NaN
#
#                                  f5ba9af421ffbf4142cf 57adef6d764fcf32199b  \
# f910338e60315f02812b05e932068f47                  NaN                  NaN
#
#                                  57a37983df905f16f732  ...  \
# f910338e60315f02812b05e932068f47                  NaN  ...
#
# ...

# %%
glob_design_data.columns.tolist()
# Out:
# ['1028d033d74dd2e24f67',
#  '9e1c545a4b490a7c3088',
#  'e7370ccd417a54394cfc',
#  'a034c30acd4658d468a4',
#  '8fd373d2d72b97b68c49',
#  '83f4b8d153f1fde2d2a8',
#  'acf7bfc2db5043ca0d0b',
#  'f5ba9af421ffbf4142cf',
#  '57adef6d764fcf32199b',
#  '57a37983df905f16f732',
#  '5145b65ed94820a0605c',
#  '210c97d661a99f3a3fd5',
#  'a19bef9a50abec7a77d3',
#  'a17745390e720d6afc3f',
#  '3c048c44f4fbd08f5398',
#  'cec5b4544e3b82d03813',
#  'c807e3d14fce5db543e1',
#  '4819fbd275ea888d3185',
#  '20113a3748ea9574ead1',
#  '68ebe610aa13d60bb971',
#  'a90a588373354ad04457',
#  '7fa93007236af2ded26b',
#  '78cd6fb7ab77e365190d',
#  'c01e7ae5c6a25c6bd829',
#  '0b24bd4c06314d590ffb',
#  '963f3cd2b7d79c9e345b',
#  'f30de959ee13e6c78d1d',
#  '66e0233a5ec44fe5d2d6',
#  'fc3d1098b8bcd5ba1395',
#  '51ef7971748330daa112',
#  'ba10dd89a541027e16fd',
#  'cadec80297897d3d77cf',
#  'eb6740e12c5f48f9a196',
#  'b6df9848c6b5ca4b59ca',
#  'd07e63344e32a108cc06',
#  'dca3a966d50dccac4a77',
#  'b8ba063877d6383cec9a',
# ...
